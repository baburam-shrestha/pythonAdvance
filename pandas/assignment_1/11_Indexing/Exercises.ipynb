# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
chipotle=pd.read_csv("chipotle.tsv",sep="\t")
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4.

# %%
chipotle.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# ### Step 5.

# %%
chipotle['choice_description'][9:30] ="no description"
chipotle[9:30]
# Out:
# /tmp/ipykernel_10277/1599869521.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chipotle['choice_description'][9:30] ="no description"
#     order_id  quantity                              item_name  \
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# 14         7         1                    Chips and Guacamole
# 15         8         1  Chips and Tomatillo-Green Chili Salsa
# 16         8         1                        Chicken Burrito
# 17         9         1                        Chicken Burrito
# ...

# %% [markdown]
# ### Step 6.

# %%
chipotle = chipotle.replace("no description",2.40)
chipotle[7:25]
# Out:
#     order_id  quantity                              item_name  \
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# 14         7         1                    Chips and Guacamole
# 15         8         1  Chips and Tomatillo-Green Chili Salsa
# 16         8         1                        Chicken Burrito
# 17         9         1                        Chicken Burrito
# 18         9         2                            Canned Soda
# 19        10         1                           Chicken Bowl
# 20        10         1                    Chips and Guacamole
# ...

# %% [markdown]
# ### Step 7.

# %%
chipotle.iloc[:3] = np.nan

# %% [markdown]
# ### Step 8.

# %%
chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0          NaN       NaN                                    NaN
# 1          NaN       NaN                                    NaN
# 2          NaN       NaN                                    NaN
# 3          1.0       1.0  Chips and Tomatillo-Green Chili Salsa
# 4          2.0       2.0                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617    1833.0       1.0                          Steak Burrito
# 4618    1833.0       1.0                          Steak Burrito
# 4619    1834.0       1.0                     Chicken Salad Bowl
# 4620    1834.0       1.0                     Chicken Salad Bowl
# 4621    1834.0       1.0                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN        NaN
# ...

# %% [markdown]
# ### Step 9.

# %%
chipotle=chipotle.dropna()

# %% [markdown]
# ### Step 10.

# %%
chipotle.reset_index(drop = True)
# Out:
#       order_id  quantity           item_name  \
# 0          2.0       2.0        Chicken Bowl
# 1          3.0       1.0        Chicken Bowl
# 2          4.0       1.0       Steak Burrito
# 3          4.0       1.0    Steak Soft Tacos
# 4          5.0       1.0       Steak Burrito
# ...        ...       ...                 ...
# 3374    1833.0       1.0       Steak Burrito
# 3375    1833.0       1.0       Steak Burrito
# 3376    1834.0       1.0  Chicken Salad Bowl
# 3377    1834.0       1.0  Chicken Salad Bowl
# 3378    1834.0       1.0  Chicken Salad Bowl
#
#                                      choice_description item_price
# 0     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 1     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 2     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 3     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 4                                                   2.4     $9.25
# ...

# %% [markdown]
# ### Step 11.

# %% [markdown]
# ### Step 12.

# %% [markdown]
# ### Step 13.

# %% [markdown]
# ### Step 14.

# %% [markdown]
# ### Step 15.

# %% [markdown]
# ### Step 16.

# %% [markdown]
# ### BONUS: Create your own question and answer it.
